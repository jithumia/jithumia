# %% [markdown]
# <a href="https://colab.research.google.com/github/jithumia/jithumia/blob/main/DVH_CSV_25oct2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Prescription = 45.0 # Gy

# %%
#def diff_to_prescribed(dose, Prescribed_dose):
#    return 100.0 + 100.0*(dose-Prescribed_dose)/Prescribed_dose

# %%
from pyEclipseDVH_v import List_txt, Load_patient, get_dmin, get_dmax, get_d_metric, Load_files_to_df

# %%
txt_files = List_txt()
txt_files
# Out:
# ['16.txt',
#  '13.txt',
#  '12.txt',
#  '11.txt',
#  '8.txt',
#  '18.txt',
#  '7.txt',
#  '9.txt',
#  '3.txt',
#  '6.txt',
#  '10.txt',
#  '4.txt',
#  '5.txt',
#  '17.txt',
#  '15.txt',
#  '19.txt',
#  '20.txt',
#  '2.txt',
#  '14.txt',
#  '21.txt']

# %%
df = Load_files_to_df(txt_files)
# Out:
# 16.txt loaded 	 patID:CR/28439 PlanID:RP_SANGRAM and number of structures is 10
# 13.txt loaded 	 patID:CP/41265 PlanID:RP_SANGRAM and number of structures is 10
# 12.txt loaded 	 patID:CP/36474 PlanID:RP_SANGRAM and number of structures is 10
# 11.txt loaded 	 patID:CT/01026 PlanID:RP-SANGRAM-N and number of structures is 12
# 8.txt loaded 	 patID:CS/18950 PlanID:RP_SANGRAM_N and number of structures is 12
# 18.txt loaded 	 patID:CR/36194 PlanID:RP_SANGRAM and number of structures is 10
# 7.txt loaded 	 patID:CR/50337 PlanID:RP_SANGRAM and number of structures is 12
# 9.txt loaded 	 patID:CS/21144 PlanID:RP_SANGRAM_N and number of structures is 12
# 3.txt loaded 	 patID:CP/40308 PlanID:RP_SANGRAM_N and number of structures is 12
# 6.txt loaded 	 patID:CR/50089 PlanID:RP_SANGRAM_N and number of structures is 12
# 10.txt loaded 	 patID:CS/50718 PlanID:RP_SANGRAM_N and number of structures is 12
# 4.txt loaded 	 patID:CR/04252 PlanID:RP_SANGRAM_N and number of structures is 12
# ...

# %%
pd.set_option('display.max_columns', None)
df

# %%
df.shape
# Out:
# (2001, 220)

# %%
df.keys().unique()
# Out:
# MultiIndex([(        'Bladder',),
#             (          'Bowel',),
#             ('Femoral heads_L',),
#             ('Femoral heads_R',),
#             (      'Kidneys_L',),
#             (      'Kidneys_R',),
#             (          'PTV45',),
#             (         'Rectum',),
#             (        'Sigmoid',),
#             (    'Spinal cord',),
#             (      'Bowel bag',),
#             (     'Kidneys_L1',),
#             (     'Kidneys_R1',),
#             (   'Spinal cord1',),
#             (          'PTVn3',),
#             (          'CTVn3',),
#             (            'PTV',),
#             (   'Tot_PTV_Node',),
#             (   'Tot_CTV_Node',),
#             (      'Rectum_RP',),
#             (     'Sigmoid_RP',),
#             ( 'Total_PTV_Node',),
#             ('Tot_Node_Margin',),
#             ( 'Femoral Head_L',),
#             ( 'Femoral Head_R',),
#             (       'Kidney_L',),
#             (       'Kidney_R',),
# ...

# %%
df.rename(columns = {'PTV 45/25':'PTV45','Bowel bag':'Bowel','SpinalCord':'Spinal cord','Kidney_R':'Kidneys_R','Kidney_L':'Kidneys_L','sigmoid':'Sigmoid','Femoral Head_L':'Femoral heads_L','Femoral Head_R':'Femoral heads_R','Kidneys_L1':'Kidneys_L','Kidneys_R1':'Kidneys_R','PTV':'PTV45','Tot_Node_Margin':'Tot_PTV_Node','Total_PTV_Node':'Tot_PTV_Node','PTVn3':'Tot_PTV_Node','CTVn3':'Tot_CTV_Node','Spinal cord1':'Spinal cord','Sigmoid_RP':'Sigmoid','CTV-N1':'Tot_CTV_Node','CTV_N1':'Tot_CTV_Node','Rectum_RP':'Rectum'} , inplace = True)

# %%
list(df.keys().unique())
# Out:
# [('Bladder',),
#  ('Bowel',),
#  ('Femoral heads_L',),
#  ('Femoral heads_R',),
#  ('Kidneys_L',),
#  ('Kidneys_R',),
#  ('PTV45',),
#  ('Rectum',),
#  ('Sigmoid',),
#  ('Spinal cord',),
#  ('Tot_PTV_Node',),
#  ('Tot_CTV_Node',)]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %%
df

# %%
import numbers

# %%
df3=df.groupby(by=df.columns, axis=1).apply(lambda g: g.mean(axis=1) if isinstance(g.iloc[0,0], numbers.Number) else g.iloc[:,0])

# %%
df2=df.groupby(by=df.columns, axis=1).apply(lambda g: g.mean(axis=1) if isinstance(g.iloc[0,0], numbers.Number) else g.iloc[:,0])

# %%
df1=df.groupby(by=df.columns, axis=1).apply(lambda g: g.mean(axis=1) if isinstance(g.iloc[0,0], numbers.Number) else g.iloc[:,0])

# %%
df1.describe()
# Out:
#         (Bladder,)     (Bowel,)  (Femoral heads_L,)  (Femoral heads_R,)  \
# count  2001.000000  2001.000000  2001.000000         2001.000000
# mean   36.132659    20.830549    15.773824           15.501788
# std    42.308666    30.875997    28.624854           28.785510
# min    0.000000     0.000000     0.000000            0.000000
# 25%    0.000000     0.000000     0.000000            0.000000
# 50%    0.067354     0.171399     0.000000            0.000000
# 75%    82.902042    32.616296    17.394200           15.028542
# max    100.000000   100.000000   100.000000          100.000000
#
#        (Kidneys_L,)  (Kidneys_R,)     (PTV45,)    (Rectum,)   (Sigmoid,)  \
# count  2001.000000   2001.000000   2001.000000  2001.000000  2001.000000
# mean   3.653664      3.535101      45.256033    40.436632    41.261537
# std    10.380499     10.710322     49.057232    45.864463    46.212169
# min    0.000000      0.000000      0.000000     0.000000     0.000000
# ...

# %%
df1

# %%
df_a = df1.drop(['Tot_CTV_Node'])
#df_a = df1.drop=(['Tot_CTV_Node'],[''])
#df_a = df1.drop=(['Tot_CTV_Node'],[''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-266849eb3f40> in <module>()
# ----> 1 df_a = df1.drop(['Tot_CTV_Node'])
#       2 #df_a = df1.drop=(['Tot_CTV_Node'],[''])
#       3 #df_a = df1.drop=(['Tot_CTV_Node'],[''])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# ...

# %%
df_a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-713f5f5879f7> in <module>()
# ----> 1 df_a
#
# NameError: name 'df_a' is not defined

# %%
df1.index
# Out:
# Float64Index([                0.0,                0.05,                 0.1,
#               0.15000000000000002,                 0.2,                0.25,
#               0.30000000000000004, 0.35000000000000003,                 0.4,
#                              0.45,
#               ...
#                 99.55000000000001,   99.60000000000001,               99.65,
#                              99.7,               99.75,   99.80000000000001,
#                 99.85000000000001,                99.9,               99.95,
#                             100.0],
#              dtype='float64', name='Dose (Gy)', length=2001)

# %%
df1
# Out:
#            (Bladder,)  (Bowel,)  (Femoral heads_L,)  (Femoral heads_R,)  \
# Dose (Gy)
# 0.00            100.0     100.0               100.0               100.0
# 0.05            100.0     100.0               100.0               100.0
# 0.10            100.0     100.0               100.0               100.0
# 0.15            100.0     100.0               100.0               100.0
# 0.20            100.0     100.0               100.0               100.0
# ...               ...       ...                 ...                 ...
# 99.80             0.0       0.0                 0.0                 0.0
# 99.85             0.0       0.0                 0.0                 0.0
# 99.90             0.0       0.0                 0.0                 0.0
# 99.95             0.0       0.0                 0.0                 0.0
# 100.00            0.0       0.0                 0.0                 0.0
#
#            (Kidneys_L,)  (Kidneys_R,)  (PTV45,)  (Rectum,)  (Sigmoid,)  \
# Dose (Gy)
# ...

# %%
ax = df1.plot(figsize=(30,10))
df2.plot(ax=ax)

# %%
from matplotlib import cm

# %%
ax=df1.plot(figsize=(15,10),marker='*',markevery=25,colormap='Paired')
df2.plot(ax=ax,marker='o',markevery=25,colormap='Paired')
df3.plot(ax=ax,marker='d',markevery=25,colormap='Paired')
#df2.plot(ax=ax,marker='o')
#df3.plot(ax=ax,marker='d')
plt.title('Average DVH for structures')
plt.ylabel('Relative Volume (%)')
plt.grid(True)
axes = plt.gca()
axes.set_xlim([0,80])
axes.set_ylim([5,100])
plt.legend()

# %%
from itertools import cycle, islice
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))

# %%
ax=df1.plot(figsize=(15,10),marker='*',markevery=25,color=my_colors)
df2.plot(ax=ax,marker='o',markevery=25,color=my_colors)
df3.plot(ax=ax,marker='d',markevery=25,color=my_colors)
#df2.plot(ax=ax,marker='o')
#df3.plot(ax=ax,marker='d')
plt.title('Average DVH for structures')
plt.ylabel('Relative Volume (%)')
plt.grid(True)
axes = plt.gca()
axes.set_xlim([0,80])
axes.set_ylim([5,100])
plt.legend()

# %%
ax=df1.plot(figsize=(15,10),marker='*',markevery=15)
#df2.plot(ax=ax,marker='o',markevery=15)
#df3.plot(ax=ax,marker='d',markevery=15)
#df2.plot(ax=ax,marker='o')
#df3.plot(ax=ax,marker='d')
plt.title('Average DVH for structures')
plt.ylabel('Relative Volume (%)')
plt.grid(True)
axes = plt.gca()
axes.set_xlim([0,100])
axes.set_ylim([5,100])
#plt.legend()
# Out:
# (5.0, 100.0)

# %%
fig = plt.figure()

for frame in [df1,df2]:
    frame.plot(figsize=(15,10),marker='*')

plt.xlim(0,60)
plt.ylim(0,100)
plt.show()
